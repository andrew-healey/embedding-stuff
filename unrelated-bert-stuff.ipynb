# %%
{
    0.2:[0.5055,0.4855,0.4994,0.4099,0.4988],
    0.4:[0.487,0.551,0.529,0.507,0.537],
    0.6:[0.524,0.597,0.616,0.589,0.568],
    0.8:[0.528,0.622,0.577,0.6,0.607],
    1.0:[0.603,0.627,0.556,0.595,0.648],
}
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

# Data from the dictionary
# data = {
#     0.2:[0.5055,0.4855,0.4994,0.4099,0.4988],
#     0.4:[0.487,0.551,0.529,0.507,0.537],
#     0.6:[0.524,0.597,0.616,0.589,0.568],
#     0.8:[0.528,0.622,0.577,0.6,0.607],
#     1.0:[0.603,0.627,0.556,0.595,0.648],
#  }
data = {0.2: {1: 0.4814416667502012,
  2: 0.5219057673898517,
  3: 0.5230185151735101,
  4: 0.4287050290930904,
  5: 0.45616062681522646},
 0.4: {1: 0.4661468575124075,
  2: 0.5286318081757405,
  3: 0.543672114017422,
  4: 0.5930672165988062,
  5: 0.5607476618686508},
 0.6: {1: 0.49944632887935275,
  2: 0.601718616924754,
  3: 0.5543919121008244,
  4: 0.5672711829293631,
  5: 0.5810647017543239},
 0.8: {1: 0.5407650419353729,
  2: 0.6041866499939695,
  3: 0.6167303037042366,
  4: 0.6434877426655812,
  5: 0.6095692136732672},
 1.0: {1: 0.5823057301255298,
  2: 0.6049327223476586,
  3: 0.5767757077878479,
  4: 0.6188422143604214,
  5: 0.6537221772887909}}
# Preparing data for plotting
ratios = list(data.keys())
all_accuracies = [values for values in data.values()]

# Plotting
plt.figure(figsize=(10, 6))
for ratio, accuracies in zip(ratios, all_accuracies):
    plt.scatter([ratio]*len(accuracies), list(accuracies.values()), label=f'Fraction {ratio}')

plt.title('Best Matthews Coefficient vs Fraction of Train Data')
plt.xlabel('Fraction of Train Data')
plt.ylabel('Best Matthews Coefficient')
plt.grid(True)
plt.legend()
plt.show()
